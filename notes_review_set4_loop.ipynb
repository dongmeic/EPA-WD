# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wdtools import *

# %%
setID = 'Set004'

# %%
review_loop(setID)
# Out:
# WD2020-0149
#                          correct_type                   correction   cor_trsqq
# 0  township number and section number  from 13 and 34 to 14 and 03  14S04W0300
# Press 'p' to pause or any other key to continue...c
# WD2017-0486
#   correct_type           correction cor_trsqq
# 1       county  from Linn to Benton       NaN
# Press 'p' to pause or any other key to continue...c
# WD2020-0635
#   correct_type                                         correction   cor_trsqq
# 2   lot number  lot number ['12004'] might be incorrect, the m...  01N01E36BC
# Press 'p' to pause or any other key to continue...c
# WD2020-0551
#   correct_type                                         correction   cor_trsqq
# 3   lot number  lot number ['2700', 'ROADS'] might be incorrec...  01S02E15CA
# Press 'p' to pause or any other key to continue...c
# WD2021-0031
#      correct_type     correction   cor_trsqq
# 4  section number  from 06 to 01  15S14E0100
# ...

# %%
review_loop_r1(setID=setID)
# Out:
# WD2022-0083
#                     county       trsqq  \
# 0   Yamhill and Washington    03S02W16
# 1   Yamhill and Washington    03S02W15
# 2   Yamhill and Washington    03S02W28
# 3   Yamhill and Washington  03S02W21CC
# 4   Yamhill and Washington  03S02W16DA
# 5   Yamhill and Washington    03S02W20
# 6   Yamhill and Washington  03S02W20DD
# 7   Yamhill and Washington  03S02W20DD
# 8   Yamhill and Washington    03S02W21
# 9   Yamhill and Washington    03S02W21
# 10  Yamhill and Washington    03S02W15
# 11  Yamhill and Washington  03S02W28BB
# 12  Yamhill and Washington  03S02W20DD
# 13  Yamhill and Washington  03S02W28BB
# 14  Yamhill and Washington    03S02W28
# 15  Yamhill and Washington    03S02W21
# 16  Yamhill and Washington    03S02W15
# 17  Yamhill and Washington  03S02W15AA
# 18  Yamhill and Washington    03S02W28
#
#                                            parcel_id  latitude   longitude  \
# 0                   1902,1903,2014,6501,ROW,All part  45.31622 -122.911130
# ...
