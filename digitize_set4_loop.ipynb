# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wdtools import *

# %%
setID = 'Set004'; nm_to_add = 2878

# %%
wd = combine_wd_tables(setID=setID, nm_to_add=nm_to_add)

# %%
matched = gpd.read_file(os.path.join(inpath + '\\output\\matched\\', f'matched_records_{setID}_edited.shp'))

# %%
unmatched = pd.read_csv(os.path.join(inpath + '\\output\\to_review\\', f'unmatched_df_{setID}_2.csv'))

# %%
matched.columns
# Out:
# Index(['wdID', 'trsqq', 'parcel_id', 'notes', 'lots', 'lot', 'ORTaxlot',
#        'record_ID', 'geometry'],
#       dtype='object')

# %%
# unmatched records based on wdID
unmatchedIDs = wd[~wd.wetdet_delin_number.isin(matched.wdID.unique())].wetdet_delin_number.unique()
len(unmatchedIDs)
# Out:
# 15

# %%
# unmatched records based record IDs
unmatchedwdIDs = unmatched.wetdet_delin_number.unique()
len(unmatchedwdIDs)
# Out:
# 22

# %%
unmatched.shape
# Out:
# (62, 25)

# %%
all([wdID in unmatchedwdIDs for wdID in unmatchedIDs])
# Out:
# False

# %%
review_loop_r1(df=unmatched, partial=True, idx=True)
# Out:
# 0.0% digitized, 22 records remained, expected to be done in about 18 hours...
# WD2022-0083
# index = 1
#                     county       trsqq  \
# 0   Yamhill and Washington    03S02W16
# 1   Yamhill and Washington  03S02W21CC
# 2   Yamhill and Washington  03S02W16DA
# 3   Yamhill and Washington    03S02W20
# 4   Yamhill and Washington  03S02W20DD
# 5   Yamhill and Washington  03S02W20DD
# 6   Yamhill and Washington    03S02W15
# 7   Yamhill and Washington    03S02W21
# 8   Yamhill and Washington    03S02W21
# 9   Yamhill and Washington    03S02W28
# 10  Yamhill and Washington    03S02W28
# 11  Yamhill and Washington  03S02W20DD
# 12  Yamhill and Washington  03S02W28BB
# 13  Yamhill and Washington    03S02W28
# 14  Yamhill and Washington  03S02W28BB
# 15  Yamhill and Washington    03S02W15
# 16  Yamhill and Washington    03S02W15
# 17  Yamhill and Washington  03S02W15AA
# 18  Yamhill and Washington    03S02W21
#
#                                            parcel_id  latitude   longitude  \
# 0                   1902,1903,2014,6501,ROW,All part  45.31622 -122.911130
# 1                                          1200p,ROW  45.31622 -122.911130
# 2                                      100p,200p,ROW  45.31622 -122.911130
# 3                           300,304,308,ROW,All part  45.31622 -122.911130
# 4                                         1200,90600  45.31622 -122.911130
# 5               90200,90300,90400,90500,ROW,All part  45.31622 -122.911130
# 6           301,390,400,500,600,700,900,ROW,All part  45.31622 -122.911130
# 7                      2300,2400,2600,2800,2900,3000  45.31622 -122.911130
# 8    3701,3801,4000,4100,4200,6500,6501,ROW,All part  45.31622 -122.911130
# 9             1000,1100,1200,1900,2200,2300,All part  45.27899 -122.944817
# 10                                       803,804,901  45.27899 -122.944817
# 11                           100,1000,90000,All part  45.31622 -122.911130
# 12                                           100,ROW  45.27899 -122.944817
# 13                  2400,2401,2402,2404,ROW,All part  45.27899 -122.944817
# 14                                     400p,502p,ROW  45.27899 -122.944817
# 15                                               800  45.31622 -122.911130
# 16                 1000,1100,1101,1800,1801,All part  45.31622 -122.911130
# 17                                    900p,1000p,ROW  45.31622 -122.911130
# 18  1702,2101,2500,2700,3200,3400,3401,3500,All part  45.31622 -122.911130
#
#     record_ID         notes missinglot
# 0        3922  ROW, Partial          N
# 1        3906  ROW, Partial          N
# 2        3907  ROW, Partial          N
# 3        3908  ROW, Partial          N
# 4        3909           NaN          N
# 5        3910  ROW, Partial          N
# 6        3921  ROW, Partial          N
# 7        3911           NaN          N
# 8        3912  ROW, Partial          N
# 9        3913       Partial          N
# 10       3905           NaN          N
# 11       3915       Partial          N
# 12       3916           ROW          N
# 13       3917  ROW, Partial          N
# 14       3914  ROW, Partial          N
# 15       3904           NaN          N
# 16       3920       Partial          N
# 17       3919  ROW, Partial          N
# 18       3918       Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 4.5% digitized, 21 records remained, expected to be done in about 17 hours...
# WD2017-0050
# index = 20
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 19  Multnomah  01N01W06BB       ROW  45.595300 -122.867100       3327   ROW
# 20  Multnomah   01N01W06B       ROW  45.595300 -122.867100       3328   ROW
# 21  Multnomah   01N01W06C       ROW  45.595300 -122.867100       3329   ROW
# 22  Multnomah   02N01W31C       ROW  45.619127 -122.862067       3330   ROW
# 23  Multnomah    02N01W31       ROW  45.619127 -122.862067       3331   ROW
# 24  Multnomah  02N01W30BC       ROW  45.619127 -122.862067       3332   ROW
#
#    missinglot
# 19          Y
# 20          Y
# 21          Y
# 22          Y
# 23          Y
# 24          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 9.1% digitized, 20 records remained, expected to be done in about 16 hours...
# WD2020-0400
# index = 26
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 25  Jefferson  11S13E12AC       ROW  44.626691 -121.110808       3063   ROW
# 26  Jefferson  11S13E12AD       ROW  44.626691 -121.110808       3064   ROW
# 27  Jefferson   11S13E12D       ROW  44.626691 -121.110808       3065   ROW
# 28  Jefferson  11S13E12DD       ROW  44.626691 -121.110808       3068   ROW
# 29  Jefferson  11S13E02DA       ROW  44.626691 -121.110808       3067   ROW
#
#    missinglot
# 25          Y
# 26          Y
# 27          Y
# 28          Y
# 29          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 13.6% digitized, 19 records remained, expected to be done in about 15 hours...
# WD2021-0183
# index = 31
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 30  Jefferson  11S13E01CD       ROW        NaN         NaN       3073   ROW
# 31  Jefferson  11S13E11DB       ROW        NaN         NaN       3071   ROW
# 32  Jefferson  11S13E11AD       ROW        NaN         NaN       3072   ROW
# 33  Jefferson  11S13E11DA       ROW        NaN         NaN       3074   ROW
# 34  Jefferson  11S13E11AC       ROW  44.629032 -121.137258       3070   ROW
#
#    missinglot
# 30          Y
# 31          Y
# 32          Y
# 33          Y
# 34          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 18.2% digitized, 18 records remained, expected to be done in about 14 hours...
# WD2018-0177
# index = 36
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 35  Multnomah  01N02E18BD       ROW  45.576273 -122.614032       3408   ROW
# 36  Multnomah  01N02E07CC       ROW  45.576273 -122.614032       3409   ROW
# 37  Multnomah  01N02E18BA       ROW  45.576273 -122.614032       3410   ROW
#
#    missinglot
# 35          Y
# 36          Y
# 37          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 22.7% digitized, 17 records remained, expected to be done in about 14 hours...
# WD2020-0208
# index = 39
#    county     trsqq     parcel_id  latitude  longitude  record_ID notes  \
# 38   Linn  12S02W22  300,400,ROWs       NaN        NaN       3232   ROW
# 39   Linn  12S02W15          ROWs       NaN        NaN       3230   ROW
# 40   Linn  12S02W23           ROW       NaN        NaN       3229   ROW
#
#    missinglot
# 38          N
# 39          Y
# 40          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 27.3% digitized, 16 records remained, expected to be done in about 13 hours...
# WD2018-0671
# index = 42
#        county     trsqq  parcel_id   latitude   longitude  record_ID    notes  \
# 41  Jefferson  10S13W30       600p  44.658959 -121.224633       3045  Partial
# 42  Jefferson  10S13W31  100p,200p  44.660000 -121.220000       3046  Partial
#
#    missinglot
# 41          N
# 42          N
# Press 'p' to pause or any key to stop...P
# Press 'a' to add the wd record or 'c' to continue...C
# 31.8% digitized, 15 records remained, expected to be done in about 12 hours...
# WD2022-0026
# index = 44
#        county     trsqq parcel_id   latitude   longitude  record_ID notes  \
# 43  Multnomah  01S06E00      Many  45.471494 -122.095475       3704  Many
# 44  Multnomah  01S05E00      Many  45.444581 -122.154343       3705  Many
#
#    missinglot
# 43          Y
# 44          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 36.4% digitized, 14 records remained, expected to be done in about 11 hours...
# WD2019-0262
# index = 46
#    county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 45   Linn  10S01W18D      300p  44.699307 -122.847701       3190  Partial
# 46   Linn  10S01W18D      300p  44.699307 -122.847701       3191  Partial
#
#    missinglot
# 45          N
# 46          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 40.9% digitized, 13 records remained, expected to be done in about 10 hours...
# WD2021-0245
# index = 48
#        county       trsqq                               parcel_id   latitude  \
# 47  Multnomah  01S03E15BB  70000,70002,70003,70004,70005,All part  45.488347
# 48  Multnomah  01S03E15BB                         6821p,6822p,ROW  45.488347
#
#      longitude  record_ID         notes missinglot
# 47 -122.677754       3667       Partial          N
# 48 -122.677754       3666  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 45.5% digitized, 12 records remained, expected to be done in about 10 hours...
# WD2019-0538
# index = 50
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 49  Jefferson  11S13E14BD       ROW  44.617829 -121.143704       3051   ROW
# 50  Jefferson  10S13W35AD       ROW  44.660384 -121.134480       3052   ROW
#
#    missinglot
# 49          Y
# 50          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 50.0% digitized, 11 records remained, expected to be done in about 9 hours...
# WD2020-0635
# index = 52
#        county       trsqq parcel_id   latitude  longitude  record_ID notes  \
# 51  Multnomah  01N01E36BC     12004  45.529286 -122.63945       3637   NaN
#
#    missinglot
# 51          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 54.5% digitized, 10 records remained, expected to be done in about 8 hours...
# WD2022-0036
# index = 53
#      county      trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 52  Yamhill  03S02W20D     1000p     45.29 -122.95552       3895  Partial
#
#    missinglot
# 52          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 59.1% digitized, 9 records remained, expected to be done in about 7 hours...
# WD2018-0276
# index = 54
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 53  Multnomah  01S01E18DA       ROW  45.481223 -122.727039       3412   ROW
#
#    missinglot
# 53          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 63.6% digitized, 8 records remained, expected to be done in about 6 hours...
# WD2020-0551
# index = 55
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 54  Multnomah  01S02E15CA  2700,ROW  45.480421 -122.549383       3614   ROW
#
#    missinglot
# 54          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 68.2% digitized, 7 records remained, expected to be done in about 6 hours...
# WD2017-0415
# index = 56
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 55  Multnomah  01N02E28DC       ROW  45.534916 -122.565683       3366   ROW
#
#    missinglot
# 55          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 72.7% digitized, 6 records remained, expected to be done in about 5 hours...
# WD2021-0594
# index = 57
#    county     trsqq parcel_id   latitude   longitude  record_ID notes  \
# 56   Linn  14S01W18       ROW  44.357473 -122.860493       3304   ROW
#
#    missinglot
# 56          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 77.3% digitized, 5 records remained, expected to be done in about 4 hours...
# WD2022-0158
# index = 58
# Decision link is not available
#    county     trsqq parcel_id  latitude  longitude  record_ID notes missinglot
# 57   Linn  02N02E07       NaN       NaN        NaN       3318   NaN        NaN
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 81.8% digitized, 4 records remained, expected to be done in about 3 hours...
# WD2017-0546
# index = 59
#        county       trsqq parcel_id  latitude  longitude  record_ID notes  \
# 58  Multnomah  02N01E15CD     11200       NaN        NaN       3389   NaN
#
#    missinglot
# 58          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 86.4% digitized, 3 records remained, expected to be done in about 2 hours...
# WD2017-0160
# index = 60
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 59  Multnomah  01S01W36DD       ROW  45.433827 -122.743467       3344   ROW
#
#    missinglot
# 59          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 90.9% digitized, 2 records remained, expected to be done in about 2 hours...
# WD2020-0632
# index = 61
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 60  Multnomah  01N01E23BC       NaN  45.558976 -122.660251       3635   NaN
#
#    missinglot
# 60        NaN
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 95.5% digitized, 1 records remained, expected to be done in about 1 hours...
# WD2018-0139
# index = 62
#        county       trsqq parcel_id  latitude  longitude  record_ID notes  \
# 61  Multnomah  01S01E20CB       ROW  45.46717 -122.72083       3402   ROW
#
#    missinglot
# 61          Y
# Press 'p' to pause or any key to stop...P
# Press 'a' to add the wd record or 'c' to continue...C

# %%
outpath = r'L:\NaturalResources\Wetlands\Local Wetland Inventory\WAPO\EPA_2022_Tasks\Task 1 WD Mapping\output'
partial = pd.read_csv(outpath + f'\\to_review\\partial_matched_{setID}.csv')

# %%
partial.columns
# Out:
# Index(['wetdet_delin_number', 'trsqq', 'parcel_id', 'address_location_desc',
#        'city', 'county', 'site_name', 'site_desc', 'latitude', 'longitude',
#        'Coord-Source', 'DocumentName', 'DecisionLink', 'is_batch_file',
#        'status_name', 'received_date', 'response_date',
#        'reissuance_response_date', 'project_id', 'site_id', 'record_ID',
#        'notes', 'recyear', 'IDyear', 'missinglot'],
#       dtype='object')

# %%
len(partial.wetdet_delin_number.unique())
# Out:
# 209

# %%
IDstoCheck = [wdID for wdID in partial.wetdet_delin_number.unique() if wdID not in unmatchedwdIDs]

# %%
len(IDstoCheck)
# Out:
# 202

# %%
toCheck_df = partial[partial.wetdet_delin_number.isin(IDstoCheck)]

# %%
toCheck_df.to_csv(outpath + f'\\to_review\\tomap_{setID}.csv', index=False)

# %%
toCheck_df = pd.read_csv(outpath + f'\\to_review\\tomap_{setID}.csv')

# %%
toadd = review_loop_r1(df=toCheck_df, partial=True, idx=True, wd_id='WD2017-0400')
# Out:
# 21.3% digitized, 159 records remained, expected to be done in about 127 hours...
# WD2017-0419
# index = 95
#    county       trsqq           parcel_id   latitude   longitude  record_ID  \
# 94   Linn  11S03W05DB      5600,RAILS,ROW  44.637831 -123.069913       3103
# 95   Linn  11S03W04CB                 100  44.637831 -123.069913       3104
# 96   Linn  11S03W05DD         100,202,300  44.637831 -123.069913       3105
# 97   Linn  11S03W05DA  600,3800,RAILS,ROW  44.637831 -123.069913       3106
# 98   Linn  11S03W04CC                 ROW  44.637831 -123.069913       3107
#
#         notes missinglot
# 94  ROW, Rail          N
# 95        NaN          N
# 96        NaN          N
# 97  ROW, Rail          N
# 98        ROW          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 21.8% digitized, 158 records remained, expected to be done in about 126 hours...
# WD2017-0578
# index = 100
#    county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 99   Linn  15S04W09  600,607p  44.285451 -123.171464       3121  Partial
#
#    missinglot
# 99          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 22.3% digitized, 157 records remained, expected to be done in about 126 hours...
# WD2018-0093
# index = 101
#     county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 100   Linn  11S03W03C  102,105p  44.637603 -123.046159       3125  Partial
#
#     missinglot
# 100          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 22.8% digitized, 156 records remained, expected to be done in about 125 hours...
# WD2018-0130
# index = 102
#     county     trsqq             parcel_id   latitude   longitude  record_ID  \
# 101   Linn  11S03W33  300,500,501,All part  44.569941 -123.049152       3127
#
#        notes missinglot
# 101  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 23.3% digitized, 155 records remained, expected to be done in about 124 hours...
# WD2018-0216
# index = 103
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 102   Linn  14S04W02      100p  44.378508 -123.150213       3136  Partial
# 103   Linn  14S04W03      100p  44.378067 -123.160978       3137  Partial
#
#     missinglot
# 102          N
# 103          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 23.8% digitized, 154 records remained, expected to be done in about 123 hours...
# WD2018-0218
# index = 105
#     county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 104   Linn  11S01W27C      400p  44.582378 -122.796762       3138  Partial
#
#     missinglot
# 104          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 24.3% digitized, 153 records remained, expected to be done in about 122 hours...
# WD2018-0486
# index = 106
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 105   Linn  14S04W03      100p  44.379211 -123.165496       3157  Partial
#
#     missinglot
# 105          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 24.8% digitized, 152 records remained, expected to be done in about 122 hours...
# WD2018-0639
# index = 107
#     county      trsqq                 parcel_id   latitude   longitude  \
# 106   Linn  11S03W19A  100,500,501,ROW,All part  44.606105 -123.094352
# 107   Linn   11S03W20             600p,603p,ROW  44.604582 -123.092700
#
#      record_ID         notes missinglot
# 106       3166  ROW, Partial          N
# 107       3167  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 25.2% digitized, 151 records remained, expected to be done in about 121 hours...
# WD2018-0667
# index = 109
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 108   Linn  11S01W31      101p  44.570097 -122.845467       3169  Partial
# 109   Linn  11S01W32       401  44.570097 -122.845467       3170      NaN
#
#     missinglot
# 108          N
# 109          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 25.7% digitized, 150 records remained, expected to be done in about 120 hours...
# WD2018-0678
# index = 111
#     county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 110   Linn  12S02W23B     1701p  44.515445 -122.903152       3172  Partial
#
#     missinglot
# 110          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 26.2% digitized, 149 records remained, expected to be done in about 119 hours...
# WD2019-0074
# index = 112
#     county     trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 111   Linn  13S04W34      100p  44.385286 -123.16509       3177  Partial
# 112   Linn  14S04W03      100p  44.385286 -123.16509       3178  Partial
#
#     missinglot
# 111          N
# 112          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 26.7% digitized, 148 records remained, expected to be done in about 118 hours...
# WD2019-0208
# index = 114
#     county     trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 113   Linn  11S02W10      400p   44.6314  -122.9211       3186  Partial
#
#     missinglot
# 113          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 27.2% digitized, 147 records remained, expected to be done in about 118 hours...
# WD2019-0264
# index = 115
#     county      trsqq  parcel_id   latitude   longitude  record_ID    notes  \
# 114   Linn  11S03W03D  101p,102p  44.641632 -123.028419       3192  Partial
#
#     missinglot
# 114          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 27.7% digitized, 146 records remained, expected to be done in about 117 hours...
# WD2019-0282
# index = 116
#     county       trsqq parcel_id  latitude   longitude  record_ID    notes  \
# 115   Linn  10S03W17DD      200p  44.69647 -123.071674       3194  Partial
#
#     missinglot
# 115          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 28.2% digitized, 145 records remained, expected to be done in about 116 hours...
# WD2019-0320
# index = 117
#     county     trsqq  parcel_id   latitude  longitude  record_ID    notes  \
# 116   Linn  12S04W01  601p,700p  44.560536 -123.12258       3196  Partial
#
#     missinglot
# 116          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 28.7% digitized, 144 records remained, expected to be done in about 115 hours...
# WD2019-0395
# index = 118
#     county      trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 117   Linn  11S03W19A     2300p  44.600634 -123.09856       3199  Partial
#
#     missinglot
# 117          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 29.2% digitized, 143 records remained, expected to be done in about 114 hours...
# WD2019-0436
# index = 119
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 118   Linn  10S01W33      600p  44.651524 -122.811079       3201  Partial
#
#     missinglot
# 118          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 29.7% digitized, 142 records remained, expected to be done in about 114 hours...
# WD2019-0492
# index = 120
#     county     trsqq parcel_id  latitude   longitude  record_ID    notes  \
# 119   Linn  11S01W04      200p  44.64893 -122.811539       3204  Partial
# 120   Linn  10S01W33      600p  44.64893 -122.811539       3205  Partial
#
#     missinglot
# 119          N
# 120          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 30.2% digitized, 141 records remained, expected to be done in about 113 hours...
# WD2019-0502
# index = 122
#     county     trsqq                     parcel_id   latitude   longitude  \
# 121   Linn  11S02W10  1302,1403,1300,1404,All part  44.628104 -122.906009
# 122   Linn  11S02W11                     700p,800p  44.628104 -122.906009
#
#      record_ID    notes missinglot
# 121       3207  Partial          N
# 122       3208  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 30.7% digitized, 140 records remained, expected to be done in about 112 hours...
# WD2019-0524
# index = 124
#     county     trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 123   Linn  09S01W29      400p  44.755961 -122.83662       3210  Partial
#
#     missinglot
# 123          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 31.2% digitized, 139 records remained, expected to be done in about 111 hours...
# WD2019-0525
# index = 125
#     county     trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 124   Linn  09S01W29      500p  44.757339 -122.83233       3211  Partial
#
#     missinglot
# 124          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 31.7% digitized, 138 records remained, expected to be done in about 110 hours...
# WD2019-0640
# index = 126
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 125   Linn  10S01W33      600p  44.651524 -122.811079       3213  Partial
#
#     missinglot
# 125          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 32.2% digitized, 137 records remained, expected to be done in about 110 hours...
# WD2020-0002
# index = 127
#     county     trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 126   Linn  12S01W31      221p  44.484147 -122.85164       3215  Partial
#
#     missinglot
# 126          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 32.7% digitized, 136 records remained, expected to be done in about 109 hours...
# WD2020-0034
# index = 128
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 127   Linn  15S04W15     3000p  44.266637 -123.155543       3218  Partial
#
#     missinglot
# 127          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 33.2% digitized, 135 records remained, expected to be done in about 108 hours...
# WD2020-0149
# index = 129
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 128   Linn  14S04W03      101p  44.390773 -123.155639       3224  Partial
# 129   Linn  13S04W34      101p  44.390773 -123.155639       3225  Partial
#
#     missinglot
# 128          N
# 129          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 33.7% digitized, 134 records remained, expected to be done in about 107 hours...
# WD2020-0319
# index = 131
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 130   Linn  14S07E00      100p  44.314204 -122.037252       3235  Partial
# 131   Linn  14S07E00      100p  44.314204 -122.037252       3236  Partial
# 132   Linn  15S06E00      100p  44.314204 -122.037252       3237  Partial
# 133   Linn  15S06E00      100p  44.314204 -122.037252       3238  Partial
# 134   Linn  14S06E00      100p  44.314204 -122.037252       3239  Partial
# 135   Linn  14S06E00      100p  44.314204 -122.037252       3240  Partial
#
#     missinglot
# 130          N
# 131          N
# 132          N
# 133          N
# 134          N
# 135          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 34.2% digitized, 133 records remained, expected to be done in about 106 hours...
# WD2020-0408
# index = 137
#     county     trsqq parcel_id  latitude   longitude  record_ID    notes  \
# 136   Linn  11S03W21      502p  44.59449 -123.065114       3245  Partial
#
#     missinglot
# 136          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 34.7% digitized, 132 records remained, expected to be done in about 106 hours...
# WD2020-0452
# index = 138
#     county      trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 137   Linn  12S01W19C      3300  44.50708 -122.86218       3247      NaN
# 138   Linn  12S01W30B       600  44.50708 -122.86218       3248      NaN
# 139   Linn  12S02W24D     1600p  44.50708 -122.86218       3249  Partial
#
#     missinglot
# 137          N
# 138          N
# 139          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 35.1% digitized, 131 records remained, expected to be done in about 105 hours...
# WD2020-0531
# index = 141
#     county       trsqq      parcel_id  latitude  longitude  record_ID  \
# 140   Linn   12S02W22B  300p,400p,ROW   44.5363  -122.9278       3253
# 141   Linn  12S02W15DC            ROW   44.5363  -122.9278       3254
# 142   Linn    12S02W16      2300p,ROW   44.5363  -122.9278       3255
# 143   Linn  12S02W22BA            ROW   44.5363  -122.9278       3256
# 144   Linn  12S02W22BB            ROW   44.5363  -122.9278       3257
# 145   Linn   12S02W22D            ROW   44.5363  -122.9278       3258
# 146   Linn   12S02W16A            ROW   44.5363  -122.9278       3259
# 147   Linn   12S02W23C            ROW   44.5363  -122.9278       3260
# 148   Linn  12S02W23CB            ROW   44.5363  -122.9278       3261
# 149   Linn   12S02W22C            ROW   44.5363  -122.9278       3262
# 150   Linn  12S02W15CD            ROW   44.5363  -122.9278       3263
# 151   Linn  12S02W10CC            ROW   44.5363  -122.9278       3264
# 152   Linn  12S02W22DA            ROW   44.5363  -122.9278       3265
# 153   Linn    12S02W21            ROW   44.5363  -122.9278       3266
#
#             notes missinglot
# 140  ROW, Partial          N
# 141           ROW          Y
# 142  ROW, Partial          N
# 143           ROW          Y
# 144           ROW          Y
# 145           ROW          Y
# 146           ROW          Y
# 147           ROW          Y
# 148           ROW          Y
# 149           ROW          Y
# 150           ROW          Y
# 151           ROW          Y
# 152           ROW          Y
# 153           ROW          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 35.6% digitized, 130 records remained, expected to be done in about 104 hours...
# WD2020-0568
# index = 155
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 154   Linn  12S02W23     1701p  44.515499 -122.902774       3267  Partial
#
#     missinglot
# 154          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 36.1% digitized, 129 records remained, expected to be done in about 103 hours...
# WD2020-0691
# index = 156
#     county     trsqq       parcel_id   latitude  longitude  record_ID  \
# 155   Linn  10S01W09  100p,1000p,ROW  44.715761 -122.80441       3273
# 156   Linn  10S01W10        300p,ROW  44.715761 -122.80441       3274
#
#             notes missinglot
# 155  ROW, Partial          N
# 156  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 36.6% digitized, 128 records remained, expected to be done in about 102 hours...
# WD2020-0699
# index = 158
#     county      trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 157   Linn  13S01E33B     1800p  44.400078 -122.69293       3275  Partial
#
#     missinglot
# 157          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 37.1% digitized, 127 records remained, expected to be done in about 102 hours...
# WD2021-0026
# index = 159
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 158   Linn  11S03W10     2401p  44.625011 -123.032195       3276  Partial
#
#     missinglot
# 158          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 37.6% digitized, 126 records remained, expected to be done in about 101 hours...
# WD2021-0033
# index = 160
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 159   Linn  11S03W20      600p  44.601166 -123.089385       3277  Partial
#
#     missinglot
# 159          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 38.1% digitized, 125 records remained, expected to be done in about 100 hours...
# WD2021-0093
# index = 161
#     county       trsqq                             parcel_id  latitude  \
# 160   Linn  11S03W06DA             11000,11100,1700,All part  44.63859
# 161   Linn  11S04W01DD                             102p,200p  44.63859
# 162   Linn  11S03W06CC  200,300,400,401,402,500,501,All part  44.63859
# 163   Linn  11S03W06CC                  502,600,800,All part  44.63859
# 164   Linn  11S03W06CD               100,5600,11500,All part  44.63859
# 165   Linn  11S03W06DC                100,6901,7001,All part  44.63859
#
#       longitude  record_ID    notes missinglot
# 160 -123.111314       3280  Partial          N
# 161 -123.111314       3281  Partial          N
# 162 -123.111314       3282  Partial          N
# 163 -123.111314       3283  Partial          N
# 164 -123.111314       3284  Partial          N
# 165 -123.111314       3285  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 38.6% digitized, 124 records remained, expected to be done in about 99 hours...
# WD2021-0263
# index = 167
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 166   Linn  15S04W04      600p  44.288343 -123.176557       3290  Partial
# 167   Linn  15S04W09      700p  44.288343 -123.176557       3291  Partial
#
#     missinglot
# 166          N
# 167          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 39.1% digitized, 123 records remained, expected to be done in about 98 hours...
# WD2021-0510
# index = 169
#     county      trsqq          parcel_id   latitude   longitude  record_ID  \
# 168   Linn   12S02W16               100p  44.531457 -122.929824       3298
# 169   Linn  12S02W16A  301,400,303p,401p  44.531457 -122.929824       3299
#
#        notes missinglot
# 168  Partial          N
# 169  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 39.6% digitized, 122 records remained, expected to be done in about 98 hours...
# WD2021-0518
# index = 171
#     county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 170   Linn  11S04W25     1302p  44.583397 -123.115986       3300  Partial
#
#     missinglot
# 170          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 40.1% digitized, 121 records remained, expected to be done in about 97 hours...
# WD2021-0654
# index = 172
#     county     trsqq  parcel_id  latitude  longitude  record_ID    notes  \
# 171   Linn  11S03W16  704p,2500   44.6207  -123.0541       3306  Partial
#
#     missinglot
# 171          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 40.6% digitized, 120 records remained, expected to be done in about 96 hours...
# WD2021-0659
# index = 173
#     county      trsqq  parcel_id   latitude   longitude  record_ID    notes  \
# 172   Linn  13S01W23B  400p,402p  44.428537 -122.775752       3307  Partial
# 173   Linn   13S01W23       400p  44.428537 -122.775752       3308  Partial
#
#     missinglot
# 172          N
# 173          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 41.1% digitized, 119 records remained, expected to be done in about 95 hours...
# WD2022-0062
# index = 175
#     county       trsqq      parcel_id   latitude   longitude  record_ID  \
# 174   Linn  11S03W08CD  201p,210,404p  44.623891 -123.082511       3312
#
#        notes missinglot
# 174  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 41.6% digitized, 118 records remained, expected to be done in about 94 hours...
# WD2022-0155
# index = 176
#     county     trsqq parcel_id   latitude   longitude  record_ID  notes  \
# 175   Linn  13S01E00     WATER  44.425262 -122.626592       3317  Water
#
#     missinglot
# 175          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 42.1% digitized, 117 records remained, expected to be done in about 94 hours...
# WD2022-0214
# index = 177
#     county      trsqq  parcel_id   latitude   longitude  record_ID notes  \
# 176   Linn  12S02W22D  1001,ROWs  44.510495 -122.910885       3320   ROW
#
#     missinglot
# 176          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 42.6% digitized, 116 records remained, expected to be done in about 93 hours...
# WD2022-0215
# index = 178
#     county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 177   Linn  13S01E27B     1800p  44.411979 -122.680125       3321  Partial
#
#     missinglot
# 177          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 43.1% digitized, 115 records remained, expected to be done in about 92 hours...
# WD2017-0052
# index = 179
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 178  Multnomah  01S01E24      200p  45.471354 -122.641964       3333  Partial
#
#     missinglot
# 178          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 43.6% digitized, 114 records remained, expected to be done in about 91 hours...
# WD2017-0057
# index = 180
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 179  Multnomah  02S01W18     1501p  45.395162 -122.851512       3334  Partial
#
#     missinglot
# 179          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 44.1% digitized, 113 records remained, expected to be done in about 90 hours...
# WD2017-0083
# index = 181
#         county      trsqq parcel_id   latitude   longitude  record_ID  \
# 180  Multnomah   01S01E23      100p  45.475810 -122.656069       3335
# 181  Multnomah  01S01E14C      100p  45.476359 -122.655556       3336
#
#        notes missinglot
# 180  Partial          N
# 181  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 44.6% digitized, 112 records remained, expected to be done in about 90 hours...
# WD2017-0114
# index = 183
#         county       trsqq                parcel_id   latitude   longitude  \
# 182  Multnomah  01S01E17DB  5700,5800,5900,6000,ROW  45.481433 -122.708258
#
#      record_ID notes missinglot
# 182       3340   ROW          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 45.0% digitized, 111 records remained, expected to be done in about 89 hours...
# WD2017-0128
# index = 184
#         county       trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 183  Multnomah  01N03E36AA      100p    45.529  -122.3783       3341  Partial
# 184  Multnomah  01N03E36AC      100p    45.529  -122.3783       3342  Partial
#
#     missinglot
# 183          N
# 184          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 45.5% digitized, 110 records remained, expected to be done in about 88 hours...
# WD2017-0336
# index = 186
#         county      trsqq                          parcel_id   latitude  \
# 185  Multnomah  01N02E16A                          2600,2700  45.571823
# 186  Multnomah   01N02E16                           100,200p  45.569090
# 187  Multnomah  01N02E16B  101,102,300,301,800,801,1100,1200  45.576525
#
#       longitude  record_ID    notes missinglot
# 185 -122.559400       3361      NaN          N
# 186 -122.574262       3362  Partial          N
# 187 -122.573620       3363      NaN          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 46.0% digitized, 109 records remained, expected to be done in about 87 hours...
# WD2017-0414
# index = 189
#         county       trsqq parcel_id   latitude   longitude  record_ID  \
# 188  Multnomah  01N03E36AA      100p  45.531563 -122.380062       3364
# 189  Multnomah  01N03E36AB      900p  45.531316 -122.381196       3365
#
#        notes missinglot
# 188  Partial          N
# 189  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 46.5% digitized, 108 records remained, expected to be done in about 86 hours...
# WD2017-0485
# index = 191
#         county       trsqq        parcel_id  latitude  longitude  record_ID  \
# 190  Multnomah    01N01E19             200p  45.55374 -122.73409       3371
# 191  Multnomah  01N01E19CA  100,200,300,ROW  45.55430 -122.73390       3372
#
#        notes missinglot
# 190  Partial          N
# 191      ROW          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 47.0% digitized, 107 records remained, expected to be done in about 86 hours...
# WD2017-0512
# index = 193
#         county       trsqq                                         parcel_id  \
# 192  Multnomah  01S02E19CC  1100,1500,1600,4800,4900,5000,5100,5200,All part
# 193  Multnomah  01S01E24DD                                       1500p,1600p
# 194  Multnomah  01S02E19CC  5300,5400,5500,5600,5700,5800,5900,6000,All part
# 195  Multnomah  01S02E19CC  6900,7700,7800,7900,8000,8100,8200,8300,All part
# 196  Multnomah  01S02E19CC  6100,6200,6300,6400,6500,6600,6700,6800,All part
#
#       latitude   longitude  record_ID    notes missinglot
# 192  45.463314 -122.617958       3375  Partial          N
# 193  45.463519 -122.620798       3376  Partial          N
# 194  45.463314 -122.617958       3377  Partial          N
# 195  45.463314 -122.617958       3378  Partial          N
# 196  45.463314 -122.617958       3379  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 47.5% digitized, 106 records remained, expected to be done in about 85 hours...
# WD2018-0012
# index = 198
#         county      trsqq       parcel_id   latitude   longitude  record_ID  \
# 197  Multnomah  01S03E24C  3600p,500p,ROW  45.468305 -122.388119       3394
#
#             notes missinglot
# 197  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 48.0% digitized, 105 records remained, expected to be done in about 84 hours...
# WD2018-0029
# index = 199
#         county      trsqq  parcel_id   latitude   longitude  record_ID  \
# 198  Multnomah   03N01W35  100p,200p  45.703244 -122.782426       3396
# 199  Multnomah  03N01W35B       500p  45.703244 -122.782426       3397
#
#        notes missinglot
# 198  Partial          N
# 199  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 48.5% digitized, 104 records remained, expected to be done in about 83 hours...
# WD2018-0113
# index = 201
#         county      trsqq parcel_id   latitude   longitude  record_ID  \
# 200  Multnomah  01N03E22D      101p  45.553141 -122.416774       3398
#
#        notes missinglot
# 200  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 49.0% digitized, 103 records remained, expected to be done in about 82 hours...
# WD2018-0125
# index = 202
#         county       trsqq                          parcel_id   latitude  \
# 201  Multnomah   01S03E18D   2000,2100,2400,2500,ROW,All part  45.477680
# 202  Multnomah   01S03E18D  1000,1800,1801,1901,1900,All part  45.477237
# 203  Multnomah  01S03E18DD                           900p,ROW  45.477237
#
#      longitude  record_ID         notes missinglot
# 201 -122.48087       3399  ROW, Partial          N
# 202 -122.48140       3400       Partial          N
# 203 -122.48140       3401  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 49.5% digitized, 102 records remained, expected to be done in about 82 hours...
# WD2018-0170
# index = 205
#         county      trsqq                parcel_id   latitude   longitude  \
# 204  Multnomah  01S03E12D  1100,1200,1300,All part  45.491859 -122.377026
#
#      record_ID    notes missinglot
# 204       3406  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 50.0% digitized, 101 records remained, expected to be done in about 81 hours...
# WD2018-0171
# index = 206
#         county       trsqq                          parcel_id   latitude  \
# 205  Multnomah  01S03E11DA  1200,1500,2100,2200,3200,All part  45.496462
#
#       longitude  record_ID    notes missinglot
# 205 -122.394486       3407  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 50.5% digitized, 100 records remained, expected to be done in about 80 hours...
# WD2018-0347
# index = 207
#         county       trsqq parcel_id   latitude   longitude  record_ID  \
# 206  Multnomah  01S03E05BB     3600p  45.517464 -122.473769       3427
#
#        notes missinglot
# 206  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 51.0% digitized, 99 records remained, expected to be done in about 79 hours...
# WD2018-0364
# index = 208
#         county       trsqq         parcel_id   latitude   longitude  \
# 207  Multnomah   01N01E02D              200p  45.592788 -122.651831
# 208  Multnomah  01N01E11AB  200,300,700,2000  45.592788 -122.651831
# 209  Multnomah   01N01E02C               600  45.592788 -122.651831
# 210  Multnomah  01N01E02CD              3700  45.592788 -122.651831
#
#      record_ID    notes missinglot
# 207       3430  Partial          N
# 208       3431      NaN          N
# 209       3432      NaN          N
# 210       3433      NaN          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 51.5% digitized, 98 records remained, expected to be done in about 78 hours...
# WD2018-0365
# index = 212
#         county       trsqq                                          parcel_id  \
# 211  Multnomah  01S01E20CD   8300,8400,8500,8600,8700,8800,8900,ROWs,All part
# 212  Multnomah  01S01E29BB  100,700,800,900,1000,1100,1200,1300,ROWs,All part
# 213  Multnomah  01S01E20CC                                 12500p,12600p,ROWs
# 214  Multnomah  01S01E20CB                         1200p,3900,4000,8300p,ROWs
# 215  Multnomah  01S01E20CA  15100,15300,15600,15700,15800,15900,ROWs,All part
# 216  Multnomah  01S01E29BC     601,602,1900,2000,2100,2200,2300,ROWs,All part
# 217  Multnomah  01S01E29BC            7600p,3400,5400,5500,6900,ROWs,All part
# 218  Multnomah  01S01E29BC   6200,6300,6800,7000,7300,7400,7500,ROWs,All part
# 219  Multnomah  01S01E29BC   3900,4000,4100,4200,5301,6000,6100,ROWs,All part
# 220  Multnomah  01S01E29BC   3000,3100,3200,3300,3500,3700,3800,ROWs,All part
# 221  Multnomah  01S01E29BC   2400,2500,2501,2600,2702,2800,2900,ROWs,All part
# 222  Multnomah  01S01E29BB                    13100,13200,13300,ROWs,All part
# 223  Multnomah  01S01E29BB  12500,12600,12700,12800,12900,13000,ROWs,All part
# 224  Multnomah  01S01E29BB        12100,12200,12300,12400,12401,ROWs,All part
# 225  Multnomah  01S01E20CA        7500,7600,8100,8300,8400,8500,ROWs,All part
# 226  Multnomah  01S01E20CC  11300,11400,11500,11600,11700,11800,ROWs,All part
# 227  Multnomah  01S01E29BB   1400,4000,4100,4200,4300,7200,7300,ROWs,All part
# 228  Multnomah  01S01E20CD        9000,9100,9200,9600,9700,9800,ROWs,All part
# 229  Multnomah  01S01E20CC  11900,12000,12100,12200,12300,12400,ROWs,All part
#
#      latitude  longitude  record_ID         notes missinglot
# 211   45.4572  -122.7203       3434  ROW, Partial          N
# 212   45.4572  -122.7203       3435  ROW, Partial          N
# 213   45.4572  -122.7203       3436  ROW, Partial          N
# 214   45.4572  -122.7203       3437  ROW, Partial          N
# 215   45.4572  -122.7203       3438  ROW, Partial          N
# 216   45.4572  -122.7203       3439  ROW, Partial          N
# 217   45.4572  -122.7203       3440  ROW, Partial          N
# 218   45.4572  -122.7203       3441  ROW, Partial          N
# 219   45.4572  -122.7203       3442  ROW, Partial          N
# 220   45.4572  -122.7203       3443  ROW, Partial          N
# 221   45.4572  -122.7203       3444  ROW, Partial          N
# 222   45.4572  -122.7203       3445  ROW, Partial          N
# 223   45.4572  -122.7203       3446  ROW, Partial          N
# 224   45.4572  -122.7203       3447  ROW, Partial          N
# 225   45.4572  -122.7203       3448  ROW, Partial          N
# 226   45.4572  -122.7203       3449  ROW, Partial          N
# 227   45.4572  -122.7203       3450  ROW, Partial          N
# 228   45.4572  -122.7203       3451  ROW, Partial          N
# 229   45.4572  -122.7203       3452  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 52.0% digitized, 97 records remained, expected to be done in about 78 hours...
# WD2018-0402
# index = 231
#         county     trsqq   parcel_id   latitude   longitude  record_ID  \
# 230  Multnomah  01N01E04  100p ,200p  45.605295 -122.693032       3458
#
#        notes missinglot
# 230  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 52.5% digitized, 96 records remained, expected to be done in about 77 hours...
# WD2018-0415
# index = 232
#         county      trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 231  Multnomah  02N01W26C      600p   45.6205  -122.7816       3459  Partial
# 232  Multnomah  02N01W26C      600p   45.6205  -122.7816       3460  Partial
# 233  Multnomah  02N01W35B      300p   45.6205  -122.7816       3461  Partial
# 234  Multnomah  02N01W35B      300p   45.6205  -122.7816       3462  Partial
#
#     missinglot
# 231          N
# 232          N
# 233          N
# 234          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 53.0% digitized, 95 records remained, expected to be done in about 76 hours...
# WD2018-0529
# index = 236
#         county       trsqq                                         parcel_id  \
# 235  Multnomah    01N03E35                                         207p,216p
# 236  Multnomah  01N03E34AB                                         100p,200p
# 237  Multnomah  01N03E34AA                        90078,90079,90080,All part
# 238  Multnomah  01N03E34AA            90068,90069,90072,90073,90074,All part
# 239  Multnomah  01N03E34AA   600,2400,2500,2600,3500,3600,3700,3702,All part
# 240  Multnomah  01N03E34AA  3800,4500,90000,90064,90065,90066,90067,All part
# 241  Multnomah  01N03E27DD      14700,14800,14900,15000,15100,17600,All part
# 242  Multnomah  01N03E35BC                          102,300,400,500,All part
#
#      latitude  longitude  record_ID    notes missinglot
# 235   45.5324  -122.4187       3474  Partial          N
# 236   45.5324  -122.4187       3475  Partial          N
# 237   45.5324  -122.4187       3476  Partial          N
# 238   45.5324  -122.4187       3477  Partial          N
# 239   45.5324  -122.4187       3478  Partial          N
# 240   45.5324  -122.4187       3479  Partial          N
# 241   45.5324  -122.4187       3480  Partial          N
# 242   45.5324  -122.4187       3481  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 53.5% digitized, 94 records remained, expected to be done in about 75 hours...
# WD2018-0533
# index = 244
#         county      trsqq                              parcel_id  latitude  \
# 243  Multnomah  01N03E29B  1400,900,600,500,400,300,ROW,All part  45.54598
# 244  Multnomah  01N03E30A                          202p,800p,ROW  45.54598
# 245  Multnomah  01N03E29A                          300p,200p,ROW  45.54598
# 246  Multnomah  01N03E29B   202,201,108,107,105,104,ROW,All part  45.54598
#
#      longitude  record_ID         notes missinglot
# 243 -122.47722       3482  ROW, Partial          N
# 244 -122.47722       3483  ROW, Partial          N
# 245 -122.47722       3484  ROW, Partial          N
# 246 -122.47722       3485  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 54.0% digitized, 93 records remained, expected to be done in about 74 hours...
# WD2018-0542
# index = 248
#         county     trsqq             parcel_id  latitude  longitude  \
# 247  Multnomah  02N01W29  300,400,500,All part   45.6341 -122.83077
# 248  Multnomah  02N01W20              400p,ROW   45.6341 -122.83077
#
#      record_ID         notes missinglot
# 247       3486       Partial          N
# 248       3487  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 54.5% digitized, 92 records remained, expected to be done in about 74 hours...
# WD2019-0006
# index = 250
#         county       trsqq                         parcel_id   latitude  \
# 249  Multnomah  01S03E14AC                         100p,200p  45.486782
# 250  Multnomah  01S03E14AB  2600,2700,2800,3000,ROW,All part  45.486782
#
#       longitude  record_ID         notes missinglot
# 249 -122.400197       3491       Partial          N
# 250 -122.400197       3492  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 55.0% digitized, 91 records remained, expected to be done in about 73 hours...
# WD2019-0034
# index = 252
#         county      trsqq        parcel_id   latitude   longitude  record_ID  \
# 251  Multnomah  01N02E18B             102p  45.573570 -122.609725       3495
# 252  Multnomah  01N02E18B             102p  45.573570 -122.609725       3496
# 253  Multnomah  01N02E18A  1300,1400,1500p  45.573349 -122.608120       3497
# 254  Multnomah  01N02E18A  1300,1400,1500p  45.573349 -122.608120       3498
#
#        notes missinglot
# 251  Partial          N
# 252  Partial          N
# 253  Partial          N
# 254  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 55.4% digitized, 90 records remained, expected to be done in about 72 hours...
# WD2019-0070
# index = 256
#         county       trsqq                     parcel_id   latitude  \
# 255  Multnomah  01S01E07CA                          4000  45.497408
# 256  Multnomah  01S01E07CB  100,200,300,400,500,All part  45.497408
#
#       longitude  record_ID    notes missinglot
# 255 -122.738493       3500      NaN          N
# 256 -122.738493       3501  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 55.9% digitized, 89 records remained, expected to be done in about 71 hours...
# WD2019-0379
# index = 258
#         county      trsqq parcel_id   latitude   longitude  record_ID  \
# 257  Multnomah  01N03E22D     1100p  45.549328 -122.422022       3523
# 258  Multnomah  01N03E22C  600,700p  45.549967 -122.424368       3524
#
#        notes missinglot
# 257  Partial          N
# 258  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 56.4% digitized, 88 records remained, expected to be done in about 70 hours...
# WD2019-0526
# index = 260
#         county       trsqq                                          parcel_id  \
# 259  Multnomah  01S02E19CC                                        200,300,ROW
# 260  Multnomah  01S02E19CD  1100,1300,1400,1500,1700,1800,1900,2300,2400,2500
# 261  Multnomah  01S02E19CA                                          16900,ROW
# 262  Multnomah  01S02E19CD       2600,2700,2800,2900,3000,3100,3200,3300,3400
# 263  Multnomah  01S02E19CD                       4400,4600,4700,4800,4900,ROW
#
#       latitude   longitude  record_ID notes missinglot
# 259  45.463866 -122.613256       3532   ROW          N
# 260  45.463866 -122.613256       3533   NaN          N
# 261  45.463866 -122.613256       3534   ROW          N
# 262  45.463866 -122.613256       3535   NaN          N
# 263  45.463866 -122.613256       3536   ROW          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 56.9% digitized, 87 records remained, expected to be done in about 70 hours...
# WD2019-0529
# index = 265
#         county     trsqq   parcel_id   latitude   longitude  record_ID  \
# 264  Multnomah  02N01W35  100p,1000p  45.617915 -122.774915       3537
#
#        notes missinglot
# 264  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 57.4% digitized, 86 records remained, expected to be done in about 69 hours...
# WD2019-0560
# index = 266
#         county       trsqq parcel_id   latitude   longitude  record_ID  \
# 265  Multnomah  01S02E22BC      400p  45.469771 -122.554124       3541
#
#        notes missinglot
# 265  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 57.9% digitized, 85 records remained, expected to be done in about 68 hours...
# WD2019-0575
# index = 267
#         county       trsqq  parcel_id   latitude   longitude  record_ID  \
# 266  Multnomah  01N01E03CC  1200p,ROW  45.592222 -122.681648       3542
# 267  Multnomah  01N01E03CC  1200p,ROW  45.592222 -122.681648       3543
# 268  Multnomah   01N01E03C       200p  45.591740 -122.678191       3544
# 269  Multnomah   01N01E03C       200p  45.591740 -122.678191       3545
# 270  Multnomah    01N01E10   200p,ROW  45.590841 -122.678415       3546
# 271  Multnomah    01N01E10   200p,ROW  45.590841 -122.678415       3547
#
#             notes missinglot
# 266  ROW, Partial          N
# 267  ROW, Partial          N
# 268       Partial          N
# 269       Partial          N
# 270  ROW, Partial          N
# 271  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 58.4% digitized, 84 records remained, expected to be done in about 67 hours...
# WD2019-0585
# index = 273
#         county       trsqq                  parcel_id   latitude  longitude  \
# 272  Multnomah  01N01W13DB  1400,1500p,1600p,1700,ROW  45.566677 -122.75065
#
#      record_ID         notes missinglot
# 272       3548  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 58.9% digitized, 83 records remained, expected to be done in about 66 hours...
# WD2019-0659
# index = 274
#         county      trsqq        parcel_id  latitude  longitude  record_ID  \
# 273  Multnomah  01N01E03C              200   45.5897  -122.6738       3550
# 274  Multnomah  01N01E03C              200   45.5897  -122.6738       3551
# 275  Multnomah   01N01E10  100,200,300,ROW   45.5897  -122.6738       3552
# 276  Multnomah   01N01E10  100,200,300,ROW   45.5897  -122.6738       3553
# 277  Multnomah  01N01E10A      300,800,ROW   45.5897  -122.6738       3554
# 278  Multnomah  01N01E10A      300,800,ROW   45.5897  -122.6738       3555
#
#     notes missinglot
# 273   NaN          N
# 274   NaN          N
# 275   ROW          N
# 276   ROW          N
# 277   ROW          N
# 278   ROW          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 59.4% digitized, 82 records remained, expected to be done in about 66 hours...
# WD2020-0116
# index = 280
#         county       trsqq       parcel_id   latitude   longitude  record_ID  \
# 279  Multnomah    01S01E22        200p,ROW  45.465177 -122.674778       3568
# 280  Multnomah  01S01E22CC       4300p,ROW  45.462367 -122.681047       3569
# 281  Multnomah  01S01E22CA  500p,2700p,ROW  45.467483 -122.673381       3570
#
#             notes missinglot
# 279  ROW, Partial          N
# 280  ROW, Partial          N
# 281  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 59.9% digitized, 81 records remained, expected to be done in about 65 hours...
# WD2020-0153
# index = 283
#         county      trsqq   parcel_id  latitude  longitude  record_ID  \
# 282  Multnomah  01N03E20B  1303,1600p    45.558  -122.4697       3576
#
#        notes missinglot
# 282  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 60.4% digitized, 80 records remained, expected to be done in about 64 hours...
# WD2020-0159
# index = 284
#         county      trsqq parcel_id   latitude   longitude  record_ID  \
# 283  Multnomah  01N02E09C      600p  45.578303 -122.575645       3577
#
#        notes missinglot
# 283  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 60.9% digitized, 79 records remained, expected to be done in about 63 hours...
# WD2020-0315
# index = 285
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 284  Multnomah  01N01W22      600p  45.557474 -122.800006       3586  Partial
#
#     missinglot
# 284          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 61.4% digitized, 78 records remained, expected to be done in about 62 hours...
# WD2020-0317
# index = 286
#         county     trsqq  parcel_id   latitude   longitude  record_ID  \
# 285  Multnomah  01N01W22  600p,800p  45.555991 -122.797449       3587
# 286  Multnomah  01N01W22  600p,800p  45.555991 -122.797449       3588
#
#        notes missinglot
# 285  Partial          N
# 286  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 61.9% digitized, 77 records remained, expected to be done in about 62 hours...
# WD2020-0329
# index = 288
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 287  Multnomah  01N02E06      300p  45.596232 -122.615095       3589  Partial
#
#     missinglot
# 287          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 62.4% digitized, 76 records remained, expected to be done in about 61 hours...
# WD2020-0334
# index = 289
#         county       trsqq                                      parcel_id  \
# 288  Multnomah  01S02E21CA  1400,1500,1600p,2100,2200,23000,2400,2500,ROW
# 289  Multnomah  01S02E21CB       4000,4100p,4200,4400,4600,4700,4900p,ROW
# 290  Multnomah  01S02E21CC                                       1800,ROW
# 291  Multnomah  01S02E21CA                        2600,2701,2800,3100,ROW
#
#       latitude   longitude  record_ID         notes missinglot
# 288  45.465369 -122.576982       3590  ROW, Partial          N
# 289  45.465369 -122.576982       3591  ROW, Partial          N
# 290  45.464836 -122.576671       3592           ROW          N
# 291  45.465369 -122.576982       3593           ROW          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 62.9% digitized, 75 records remained, expected to be done in about 60 hours...
# WD2020-0336
# index = 293
#         county      trsqq parcel_id   latitude   longitude  record_ID  \
# 292  Multnomah  01N02E09C  600p,ROW  45.580223 -122.576885       3594
#
#             notes missinglot
# 292  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 63.4% digitized, 74 records remained, expected to be done in about 59 hours...
# WD2020-0539
# index = 294
#         county       trsqq     parcel_id   latitude   longitude  record_ID  \
# 293  Multnomah  01S01E10DB  201p,300,400  45.495001 -122.669755       3610
#
#        notes missinglot
# 293  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 63.9% digitized, 73 records remained, expected to be done in about 58 hours...
# WD2020-0652
# index = 295
#         county       trsqq parcel_id   latitude   longitude  record_ID  \
# 294  Multnomah  01S01E20CB     1600p  45.468504 -122.720992       3638
#
#        notes missinglot
# 294  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 64.4% digitized, 72 records remained, expected to be done in about 58 hours...
# WD2020-0661
# index = 296
#         county       trsqq parcel_id   latitude  longitude  record_ID notes  \
# 295  Multnomah  01S01E33CC   100,ROW  45.436126 -122.69823       3639   ROW
#
#     missinglot
# 295          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 64.9% digitized, 71 records remained, expected to be done in about 57 hours...
# WD2021-0022
# index = 297
#         county       trsqq                        parcel_id   latitude  \
# 296  Multnomah  01S02E19CC  400,500,1300,1400,1401,1402,ROW  45.462396
# 297  Multnomah   01S01E24D                             200p  45.463365
# 298  Multnomah  01S01E24DD                            1600p  45.463365
# 299  Multnomah  01S02E19CC     7200,7700,7900,9100,All part  45.462396
#
#       longitude  record_ID    notes missinglot
# 296 -122.616189       3642      ROW          N
# 297 -122.616189       3643  Partial          N
# 298 -122.616189       3644  Partial          N
# 299 -122.616189       3645  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 65.3% digitized, 70 records remained, expected to be done in about 56 hours...
# WD2021-0048
# index = 301
#         county       trsqq parcel_id   latitude   longitude  record_ID  \
# 300  Multnomah  01N01E03AB       400  45.605015 -122.666653       3647
# 301  Multnomah  01N01E03AA      300p  45.604466 -122.665528       3648
#
#        notes missinglot
# 300      NaN          N
# 301  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 65.8% digitized, 69 records remained, expected to be done in about 55 hours...
# WD2021-0065
# index = 303
#         county      trsqq                 parcel_id   latitude   longitude  \
# 302  Multnomah   02N01W35                 300p,400p  45.616739 -122.777397
# 303  Multnomah  02N01W35A  100,500,600,700,All part  45.617599 -122.773258
# 304  Multnomah  02N01W35B      100,300,400,All part  45.617510 -122.784378
# 305  Multnomah   02N01W34                      300p  45.613236 -122.795835
#
#      record_ID    notes missinglot
# 302       3649  Partial          N
# 303       3650  Partial          N
# 304       3651  Partial          N
# 305       3652  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 66.3% digitized, 68 records remained, expected to be done in about 54 hours...
# WD2021-0209
# index = 307
#         county       trsqq      parcel_id  latitude   longitude  record_ID  \
# 306  Multnomah  01N03E33BA       100p,ROW  45.53343 -122.446099       3660
# 307  Multnomah  01N03E28CD      2000p,ROW  45.53343 -122.446099       3661
# 308  Multnomah    01N03E28      2000p,ROW  45.53343 -122.446099       3662
# 309  Multnomah  01N03E28DC     12100p,ROW  45.53343 -122.446099       3663
# 310  Multnomah    01N03E33  205p,210p,ROW  45.53343 -122.446099       3664
# 311  Multnomah   01N03E33A       400p,ROW  45.53343 -122.446099       3665
#
#             notes missinglot
# 306  ROW, Partial          N
# 307  ROW, Partial          N
# 308  ROW, Partial          N
# 309  ROW, Partial          N
# 310  ROW, Partial          N
# 311  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 66.8% digitized, 67 records remained, expected to be done in about 54 hours...
# WD2021-0286
# index = 313
#         county       trsqq               parcel_id   latitude   longitude  \
# 312  Multnomah  01S03E17BC               400p,500p  45.486984 -122.474602
# 313  Multnomah  01S03E17BB  900,1800,1900,All part  45.486745 -122.471300
#
#      record_ID    notes missinglot
# 312       3668  Partial          N
# 313       3669  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 67.3% digitized, 66 records remained, expected to be done in about 53 hours...
# WD2021-0289
# index = 315
#         county       trsqq                    parcel_id   latitude  \
# 314  Multnomah  01S01E15CB  1000,1100,1200,ROW,All part  45.481397
#
#       longitude  record_ID         notes missinglot
# 314 -122.677485       3670  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 67.8% digitized, 65 records remained, expected to be done in about 52 hours...
# WD2021-0295
# index = 316
#         county      trsqq             parcel_id   latitude   longitude  \
# 315  Multnomah  01N03E23B     205p,207p,206,ROW  45.560306 -122.400338
# 316  Multnomah  01N03E23B     205p,207p,206,ROW  45.560306 -122.400338
# 317  Multnomah  01N03E22C              104p,ROW  45.554831 -122.429261
# 318  Multnomah  01N03E22C              104p,ROW  45.554831 -122.429261
# 319  Multnomah   01N03E23  108,109,300,All part  45.559081 -122.466225
# 320  Multnomah   01N03E23  108,109,300,All part  45.559081 -122.466225
# 321  Multnomah  01N03E22A         100p,200p,300  45.556609 -122.425187
# 322  Multnomah  01N03E22A         100p,200p,300  45.556609 -122.425187
# 323  Multnomah   01N03E22         300p,301p,ROW  45.554831 -122.429261
# 324  Multnomah   01N03E22         300p,301p,ROW  45.554831 -122.429261
#
#      record_ID         notes missinglot
# 315       3671  ROW, Partial          N
# 316       3672  ROW, Partial          N
# 317       3673  ROW, Partial          N
# 318       3674  ROW, Partial          N
# 319       3675       Partial          N
# 320       3676       Partial          N
# 321       3677       Partial          N
# 322       3678       Partial          N
# 323       3679  ROW, Partial          N
# 324       3680  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 68.3% digitized, 64 records remained, expected to be done in about 51 hours...
# WD2021-0346
# index = 326
#         county       trsqq                     parcel_id   latitude  \
# 325  Multnomah  01S02E22BA                          300p  45.475157
# 326  Multnomah  01S02E22AB  300,400p,500,600,700,800,900  45.475157
# 327  Multnomah  01S02E22AB         1000,1100p,1200,1300p  45.475157
#
#       longitude  record_ID    notes missinglot
# 325 -122.546328       3684  Partial          N
# 326 -122.546328       3685  Partial          N
# 327 -122.546328       3686  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 68.8% digitized, 63 records remained, expected to be done in about 50 hours...
# WD2021-0398
# index = 329
#         county      trsqq parcel_id   latitude   longitude  record_ID  \
# 328  Multnomah  01N03E29A      900p  45.542031 -122.460579       3692
#
#        notes missinglot
# 328  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 69.3% digitized, 62 records remained, expected to be done in about 50 hours...
# WD2021-0450
# index = 330
#         county     trsqq parcel_id  latitude   longitude  record_ID    notes  \
# 329  Multnomah  03N01W31      500p  45.70021 -122.860469       3695  Partial
#
#     missinglot
# 329          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 69.8% digitized, 61 records remained, expected to be done in about 49 hours...
# WD2021-0482
# index = 331
#         county     trsqq parcel_id  latitude   longitude  record_ID    notes  \
# 330  Multnomah  02N01W34  200p,201  45.61846 -122.804976       3696  Partial
#
#     missinglot
# 330          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 70.3% digitized, 60 records remained, expected to be done in about 48 hours...
# WD2021-0653
# index = 332
#         county      trsqq parcel_id   latitude  longitude  record_ID    notes  \
# 331  Multnomah  01S03E20D     1200p  45.464835 -122.46644       3701  Partial
#
#     missinglot
# 331          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 70.8% digitized, 59 records remained, expected to be done in about 47 hours...
# WD2022-0041
# index = 333
#         county       trsqq parcel_id  latitude   longitude  record_ID  \
# 332  Multnomah  01N03E25DC     1800p  45.53673 -122.381308       3707
#
#        notes missinglot
# 332  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 71.3% digitized, 58 records remained, expected to be done in about 46 hours...
# WD2022-0074
# index = 334
#         county       trsqq        parcel_id   latitude   longitude  record_ID  \
# 333  Multnomah  02N01W20BD  2300p,2400p,ROW  45.642736 -122.837816       3710
# 334  Multnomah   02N01W20B         700p,ROW  45.642736 -122.837816       3711
#
#             notes missinglot
# 333  ROW, Partial          N
# 334  ROW, Partial          N

# %%
#tocheckIDs = ['WD2021-0250','WD2019-0544','WD2020-0229','WD2020-0677','WD2021-0252','WD2021-0616','WD2017-0001']

# %%
#review_loop_r1(wdid_list=tocheckIDs, partial=True, idx=True, wddf=wd)
