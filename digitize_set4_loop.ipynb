# %%
# %load_ext autoreload
# %autoreload 2

# %%
from wdtools import *

# %%
setID = 'Set004'; nm_to_add = 2878

# %%
wd = combine_wd_tables(setID=setID, nm_to_add=nm_to_add)

# %%
matched = gpd.read_file(os.path.join(inpath + '\\output\\matched\\', f'matched_records_{setID}_edited.shp'))

# %%
unmatched = pd.read_csv(os.path.join(inpath + '\\output\\to_review\\', f'unmatched_df_{setID}_2.csv'))

# %%
matched.columns
# Out:
# Index(['wdID', 'trsqq', 'parcel_id', 'notes', 'lots', 'lot', 'ORTaxlot',
#        'record_ID', 'geometry'],
#       dtype='object')

# %%
# unmatched records based on wdID
unmatchedIDs = wd[~wd.wetdet_delin_number.isin(matched.wdID.unique())].wetdet_delin_number.unique()
len(unmatchedIDs)
# Out:
# 15

# %%
# unmatched records based record IDs
unmatchedwdIDs = unmatched.wetdet_delin_number.unique()
len(unmatchedwdIDs)
# Out:
# 22

# %%
unmatched.shape
# Out:
# (62, 25)

# %%
all([wdID in unmatchedwdIDs for wdID in unmatchedIDs])
# Out:
# False

# %%
review_loop_r1(df=unmatched, partial=True, idx=True)
# Out:
# 0.0% digitized, 22 records remained, expected to be done in about 18 hours...
# WD2022-0083
# index = 1
#                     county       trsqq  \
# 0   Yamhill and Washington    03S02W16
# 1   Yamhill and Washington  03S02W21CC
# 2   Yamhill and Washington  03S02W16DA
# 3   Yamhill and Washington    03S02W20
# 4   Yamhill and Washington  03S02W20DD
# 5   Yamhill and Washington  03S02W20DD
# 6   Yamhill and Washington    03S02W15
# 7   Yamhill and Washington    03S02W21
# 8   Yamhill and Washington    03S02W21
# 9   Yamhill and Washington    03S02W28
# 10  Yamhill and Washington    03S02W28
# 11  Yamhill and Washington  03S02W20DD
# 12  Yamhill and Washington  03S02W28BB
# 13  Yamhill and Washington    03S02W28
# 14  Yamhill and Washington  03S02W28BB
# 15  Yamhill and Washington    03S02W15
# 16  Yamhill and Washington    03S02W15
# 17  Yamhill and Washington  03S02W15AA
# 18  Yamhill and Washington    03S02W21
#
#                                            parcel_id  latitude   longitude  \
# 0                   1902,1903,2014,6501,ROW,All part  45.31622 -122.911130
# 1                                          1200p,ROW  45.31622 -122.911130
# 2                                      100p,200p,ROW  45.31622 -122.911130
# 3                           300,304,308,ROW,All part  45.31622 -122.911130
# 4                                         1200,90600  45.31622 -122.911130
# 5               90200,90300,90400,90500,ROW,All part  45.31622 -122.911130
# 6           301,390,400,500,600,700,900,ROW,All part  45.31622 -122.911130
# 7                      2300,2400,2600,2800,2900,3000  45.31622 -122.911130
# 8    3701,3801,4000,4100,4200,6500,6501,ROW,All part  45.31622 -122.911130
# 9             1000,1100,1200,1900,2200,2300,All part  45.27899 -122.944817
# 10                                       803,804,901  45.27899 -122.944817
# 11                           100,1000,90000,All part  45.31622 -122.911130
# 12                                           100,ROW  45.27899 -122.944817
# 13                  2400,2401,2402,2404,ROW,All part  45.27899 -122.944817
# 14                                     400p,502p,ROW  45.27899 -122.944817
# 15                                               800  45.31622 -122.911130
# 16                 1000,1100,1101,1800,1801,All part  45.31622 -122.911130
# 17                                    900p,1000p,ROW  45.31622 -122.911130
# 18  1702,2101,2500,2700,3200,3400,3401,3500,All part  45.31622 -122.911130
#
#     record_ID         notes missinglot
# 0        3922  ROW, Partial          N
# 1        3906  ROW, Partial          N
# 2        3907  ROW, Partial          N
# 3        3908  ROW, Partial          N
# 4        3909           NaN          N
# 5        3910  ROW, Partial          N
# 6        3921  ROW, Partial          N
# 7        3911           NaN          N
# 8        3912  ROW, Partial          N
# 9        3913       Partial          N
# 10       3905           NaN          N
# 11       3915       Partial          N
# 12       3916           ROW          N
# 13       3917  ROW, Partial          N
# 14       3914  ROW, Partial          N
# 15       3904           NaN          N
# 16       3920       Partial          N
# 17       3919  ROW, Partial          N
# 18       3918       Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 4.5% digitized, 21 records remained, expected to be done in about 17 hours...
# WD2017-0050
# index = 20
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 19  Multnomah  01N01W06BB       ROW  45.595300 -122.867100       3327   ROW
# 20  Multnomah   01N01W06B       ROW  45.595300 -122.867100       3328   ROW
# 21  Multnomah   01N01W06C       ROW  45.595300 -122.867100       3329   ROW
# 22  Multnomah   02N01W31C       ROW  45.619127 -122.862067       3330   ROW
# 23  Multnomah    02N01W31       ROW  45.619127 -122.862067       3331   ROW
# 24  Multnomah  02N01W30BC       ROW  45.619127 -122.862067       3332   ROW
#
#    missinglot
# 19          Y
# 20          Y
# 21          Y
# 22          Y
# 23          Y
# 24          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 9.1% digitized, 20 records remained, expected to be done in about 16 hours...
# WD2020-0400
# index = 26
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 25  Jefferson  11S13E12AC       ROW  44.626691 -121.110808       3063   ROW
# 26  Jefferson  11S13E12AD       ROW  44.626691 -121.110808       3064   ROW
# 27  Jefferson   11S13E12D       ROW  44.626691 -121.110808       3065   ROW
# 28  Jefferson  11S13E12DD       ROW  44.626691 -121.110808       3068   ROW
# 29  Jefferson  11S13E02DA       ROW  44.626691 -121.110808       3067   ROW
#
#    missinglot
# 25          Y
# 26          Y
# 27          Y
# 28          Y
# 29          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 13.6% digitized, 19 records remained, expected to be done in about 15 hours...
# WD2021-0183
# index = 31
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 30  Jefferson  11S13E01CD       ROW        NaN         NaN       3073   ROW
# 31  Jefferson  11S13E11DB       ROW        NaN         NaN       3071   ROW
# 32  Jefferson  11S13E11AD       ROW        NaN         NaN       3072   ROW
# 33  Jefferson  11S13E11DA       ROW        NaN         NaN       3074   ROW
# 34  Jefferson  11S13E11AC       ROW  44.629032 -121.137258       3070   ROW
#
#    missinglot
# 30          Y
# 31          Y
# 32          Y
# 33          Y
# 34          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 18.2% digitized, 18 records remained, expected to be done in about 14 hours...
# WD2018-0177
# index = 36
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 35  Multnomah  01N02E18BD       ROW  45.576273 -122.614032       3408   ROW
# 36  Multnomah  01N02E07CC       ROW  45.576273 -122.614032       3409   ROW
# 37  Multnomah  01N02E18BA       ROW  45.576273 -122.614032       3410   ROW
#
#    missinglot
# 35          Y
# 36          Y
# 37          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 22.7% digitized, 17 records remained, expected to be done in about 14 hours...
# WD2020-0208
# index = 39
#    county     trsqq     parcel_id  latitude  longitude  record_ID notes  \
# 38   Linn  12S02W22  300,400,ROWs       NaN        NaN       3232   ROW
# 39   Linn  12S02W15          ROWs       NaN        NaN       3230   ROW
# 40   Linn  12S02W23           ROW       NaN        NaN       3229   ROW
#
#    missinglot
# 38          N
# 39          Y
# 40          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 27.3% digitized, 16 records remained, expected to be done in about 13 hours...
# WD2018-0671
# index = 42
#        county     trsqq  parcel_id   latitude   longitude  record_ID    notes  \
# 41  Jefferson  10S13W30       600p  44.658959 -121.224633       3045  Partial
# 42  Jefferson  10S13W31  100p,200p  44.660000 -121.220000       3046  Partial
#
#    missinglot
# 41          N
# 42          N
# Press 'p' to pause or any key to stop...P
# Press 'a' to add the wd record or 'c' to continue...C
# 31.8% digitized, 15 records remained, expected to be done in about 12 hours...
# WD2022-0026
# index = 44
#        county     trsqq parcel_id   latitude   longitude  record_ID notes  \
# 43  Multnomah  01S06E00      Many  45.471494 -122.095475       3704  Many
# 44  Multnomah  01S05E00      Many  45.444581 -122.154343       3705  Many
#
#    missinglot
# 43          Y
# 44          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 36.4% digitized, 14 records remained, expected to be done in about 11 hours...
# WD2019-0262
# index = 46
#    county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 45   Linn  10S01W18D      300p  44.699307 -122.847701       3190  Partial
# 46   Linn  10S01W18D      300p  44.699307 -122.847701       3191  Partial
#
#    missinglot
# 45          N
# 46          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 40.9% digitized, 13 records remained, expected to be done in about 10 hours...
# WD2021-0245
# index = 48
#        county       trsqq                               parcel_id   latitude  \
# 47  Multnomah  01S03E15BB  70000,70002,70003,70004,70005,All part  45.488347
# 48  Multnomah  01S03E15BB                         6821p,6822p,ROW  45.488347
#
#      longitude  record_ID         notes missinglot
# 47 -122.677754       3667       Partial          N
# 48 -122.677754       3666  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 45.5% digitized, 12 records remained, expected to be done in about 10 hours...
# WD2019-0538
# index = 50
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 49  Jefferson  11S13E14BD       ROW  44.617829 -121.143704       3051   ROW
# 50  Jefferson  10S13W35AD       ROW  44.660384 -121.134480       3052   ROW
#
#    missinglot
# 49          Y
# 50          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 50.0% digitized, 11 records remained, expected to be done in about 9 hours...
# WD2020-0635
# index = 52
#        county       trsqq parcel_id   latitude  longitude  record_ID notes  \
# 51  Multnomah  01N01E36BC     12004  45.529286 -122.63945       3637   NaN
#
#    missinglot
# 51          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 54.5% digitized, 10 records remained, expected to be done in about 8 hours...
# WD2022-0036
# index = 53
#      county      trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 52  Yamhill  03S02W20D     1000p     45.29 -122.95552       3895  Partial
#
#    missinglot
# 52          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 59.1% digitized, 9 records remained, expected to be done in about 7 hours...
# WD2018-0276
# index = 54
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 53  Multnomah  01S01E18DA       ROW  45.481223 -122.727039       3412   ROW
#
#    missinglot
# 53          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 63.6% digitized, 8 records remained, expected to be done in about 6 hours...
# WD2020-0551
# index = 55
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 54  Multnomah  01S02E15CA  2700,ROW  45.480421 -122.549383       3614   ROW
#
#    missinglot
# 54          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 68.2% digitized, 7 records remained, expected to be done in about 6 hours...
# WD2017-0415
# index = 56
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 55  Multnomah  01N02E28DC       ROW  45.534916 -122.565683       3366   ROW
#
#    missinglot
# 55          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 72.7% digitized, 6 records remained, expected to be done in about 5 hours...
# WD2021-0594
# index = 57
#    county     trsqq parcel_id   latitude   longitude  record_ID notes  \
# 56   Linn  14S01W18       ROW  44.357473 -122.860493       3304   ROW
#
#    missinglot
# 56          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 77.3% digitized, 5 records remained, expected to be done in about 4 hours...
# WD2022-0158
# index = 58
# Decision link is not available
#    county     trsqq parcel_id  latitude  longitude  record_ID notes missinglot
# 57   Linn  02N02E07       NaN       NaN        NaN       3318   NaN        NaN
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 81.8% digitized, 4 records remained, expected to be done in about 3 hours...
# WD2017-0546
# index = 59
#        county       trsqq parcel_id  latitude  longitude  record_ID notes  \
# 58  Multnomah  02N01E15CD     11200       NaN        NaN       3389   NaN
#
#    missinglot
# 58          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 86.4% digitized, 3 records remained, expected to be done in about 2 hours...
# WD2017-0160
# index = 60
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 59  Multnomah  01S01W36DD       ROW  45.433827 -122.743467       3344   ROW
#
#    missinglot
# 59          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 90.9% digitized, 2 records remained, expected to be done in about 2 hours...
# WD2020-0632
# index = 61
#        county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 60  Multnomah  01N01E23BC       NaN  45.558976 -122.660251       3635   NaN
#
#    missinglot
# 60        NaN
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 95.5% digitized, 1 records remained, expected to be done in about 1 hours...
# WD2018-0139
# index = 62
#        county       trsqq parcel_id  latitude  longitude  record_ID notes  \
# 61  Multnomah  01S01E20CB       ROW  45.46717 -122.72083       3402   ROW
#
#    missinglot
# 61          Y
# Press 'p' to pause or any key to stop...P
# Press 'a' to add the wd record or 'c' to continue...C

# %%
outpath = r'L:\NaturalResources\Wetlands\Local Wetland Inventory\WAPO\EPA_2022_Tasks\Task 1 WD Mapping\output'
partial = pd.read_csv(outpath + f'\\to_review\\partial_matched_{setID}.csv')

# %%
partial.columns
# Out:
# Index(['wetdet_delin_number', 'trsqq', 'parcel_id', 'address_location_desc',
#        'city', 'county', 'site_name', 'site_desc', 'latitude', 'longitude',
#        'Coord-Source', 'DocumentName', 'DecisionLink', 'is_batch_file',
#        'status_name', 'received_date', 'response_date',
#        'reissuance_response_date', 'project_id', 'site_id', 'record_ID',
#        'notes', 'recyear', 'IDyear', 'missinglot'],
#       dtype='object')

# %%
len(partial.wetdet_delin_number.unique())
# Out:
# 209

# %%
IDstoCheck = [wdID for wdID in partial.wetdet_delin_number.unique() if wdID not in unmatchedwdIDs]

# %%
len(IDstoCheck)
# Out:
# 202

# %%
toCheck_df = partial[partial.wetdet_delin_number.isin(IDstoCheck)]

# %%
toCheck_df.to_csv(outpath + f'\\to_review\\tomap_{setID}.csv', index=False)

# %%
toCheck_df = pd.read_csv(outpath + f'\\to_review\\tomap_{setID}.csv')

# %%
toadd = review_loop_r1(df=toCheck_df, partial=True, idx=True, wd_id='WD2017-0400')
# Out:
# 8.9% digitized, 184 records remained, expected to be done in about 147 hours...
# WD2017-0536
# index = 47
#         county     trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 46  Hood River  01S09E00      100p   45.4607  -121.6528       2974  Partial
#
#    missinglot
# 46          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 9.4% digitized, 183 records remained, expected to be done in about 146 hours...
# WD2018-0002
# index = 48
#         county     trsqq parcel_id   latitude   longitude  record_ID  \
# 47  Hood River  03S09E00  100p,ROW  45.319481 -121.628633       2975
#
#            notes missinglot
# 47  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 9.9% digitized, 182 records remained, expected to be done in about 146 hours...
# WD2018-0094
# index = 49
#         county      trsqq                parcel_id  latitude  longitude  \
# 48  Hood River  02N10E11B  1603,2501,2503,All part   45.6735  -121.5403
#
#     record_ID    notes missinglot
# 48       2979  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 10.4% digitized, 181 records remained, expected to be done in about 145 hours...
# WD2018-0385
# index = 50
#         county     trsqq  parcel_id   latitude   longitude  record_ID  \
# 49  Hood River  02N09E00  100p,101p  45.641757 -121.676012       2980
# 50  Hood River  02N09E00  100p,101p  45.641757 -121.676012       2981
#
#       notes missinglot
# 49  Partial          N
# 50  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 10.9% digitized, 180 records remained, expected to be done in about 144 hours...
# WD2018-0395
# index = 52
#         county     trsqq                    parcel_id   latitude   longitude  \
# 51  Hood River  02N10E33                    100p,200p  45.606238 -121.555565
# 52  Hood River  02N10E28                        4600p  45.606238 -121.555565
# 53  Hood River  02N10E34  1500,1600,1700,ROW,All part  45.606238 -121.555565
# 54  Hood River  02N10E27              6800p,7100p,ROW  45.606238 -121.555565
#
#     record_ID         notes missinglot
# 51       2983       Partial          N
# 52       2984       Partial          N
# 53       2985  ROW, Partial          N
# 54       2986  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 11.4% digitized, 179 records remained, expected to be done in about 143 hours...
# WD2018-0398
# index = 56
#         county       trsqq parcel_id   latitude  longitude  record_ID  \
# 55  Hood River  03N10E26CC     1000p  45.710691 -121.54117       2987
#
#       notes missinglot
# 55  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 11.9% digitized, 178 records remained, expected to be done in about 142 hours...
# WD2019-0202
# index = 57
#         county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 56  Hood River  03N10E34CC   100,ROW  45.695024 -121.560108       2992   ROW
#
#    missinglot
# 56          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 12.4% digitized, 177 records remained, expected to be done in about 142 hours...
# WD2019-0389
# index = 58
#         county       trsqq parcel_id   latitude   longitude  record_ID notes  \
# 57  Hood River  03N10E25CB       ROW  45.712225 -121.519843       2994   ROW
# 58  Hood River    03N10E25       ROW  45.712225 -121.519843       2995   ROW
#
#    missinglot
# 57          Y
# 58          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 12.9% digitized, 176 records remained, expected to be done in about 141 hours...
# WD2019-0493
# index = 60
#         county     trsqq                 parcel_id  latitude  longitude  \
# 59  Hood River  03N10E32                       ROW  45.70480 -121.59190
# 60  Hood River  03N09E36                  100p,ROW  45.69509 -121.67145
# 61  Hood River  03N09E34                  400p,ROW  45.69530 -121.67111
# 62  Hood River  03N09E35             100p,101p,ROW  45.69509 -121.67145
# 63  Hood River  03N10E31  100,101,200,ROW,All part  45.69509 -121.67145
#
#     record_ID         notes missinglot
# 59       2999           ROW          Y
# 60       3000  ROW, Partial          N
# 61       3001  ROW, Partial          N
# 62       3002  ROW, Partial          N
# 63       3003  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 13.4% digitized, 175 records remained, expected to be done in about 140 hours...
# WD2019-0582
# index = 65
#         county       trsqq parcel_id  latitude  longitude  record_ID notes  \
# 64  Hood River  03N10E25CB       ROW    45.712   -121.519       3004   ROW
# 65  Hood River    03N10E25       ROW    45.712   -121.519       3005   ROW
#
#    missinglot
# 64          Y
# 65          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 13.9% digitized, 174 records remained, expected to be done in about 139 hours...
# WD2020-0438
# index = 67
#         county       trsqq        parcel_id   latitude   longitude  record_ID  \
# 66  Hood River  03N10E26CC  1000p,1001,1002  45.708293 -121.542911       3010
# 67  Hood River  03N10E26CC  1000p,1001,1002  45.708293 -121.542911       3011
#
#       notes missinglot
# 66  Partial          N
# 67  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 14.4% digitized, 173 records remained, expected to be done in about 138 hours...
# WD2020-0491
# index = 69
#         county       trsqq        parcel_id   latitude   longitude  record_ID  \
# 68  Hood River   03N10E27D  2201,2202,2400p  45.709283 -121.545356       3012
# 69  Hood River  03N10E27DD             4000  45.709283 -121.545356       3013
#
#       notes missinglot
# 68  Partial          N
# 69      NaN          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 14.9% digitized, 172 records remained, expected to be done in about 138 hours...
# WD2020-0644
# index = 71
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 70  Hood River  02N09E00      200p  45.626093 -121.743827       3018  Partial
#
#    missinglot
# 70          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 15.3% digitized, 171 records remained, expected to be done in about 137 hours...
# WD2021-0553
# index = 72
#         county       trsqq parcel_id   latitude  longitude  record_ID  \
# 71  Hood River  03N10E34AC     3100p  45.700563 -121.55058       3024
#
#       notes missinglot
# 71  Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 15.8% digitized, 170 records remained, expected to be done in about 136 hours...
# WD2021-0572
# index = 73
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 72  Hood River  03S09E00      101p  45.343878 -121.671795       3025  Partial
#
#    missinglot
# 72          N
# Press 'p' to pause or any key to stop...P
# Press 'a' to add the wd record or 'c' to continue...C
# 16.3% digitized, 169 records remained, expected to be done in about 135 hours...
# WD2021-0575
# index = 74
#         county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 73  Hood River  01S10E00      100p  45.438361 -121.533477       3026  Partial
# 74  Hood River  02S10E00      100p  45.315578 -121.514645       3027  Partial
#
#    missinglot
# 73          N
# 74          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 16.8% digitized, 168 records remained, expected to be done in about 134 hours...
# WD2020-0326
# index = 76
#        county       trsqq      parcel_id   latitude   longitude  record_ID  \
# 75  Jefferson  11S13E12DB           100p  44.624898 -121.113738       3054
# 76  Jefferson   11S13E12D  206p,800p,ROW  44.624898 -121.113738       3055
#
#            notes missinglot
# 75       Partial          N
# 76  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 17.3% digitized, 167 records remained, expected to be done in about 134 hours...
# WD2020-0395
# index = 78
#        county       trsqq                 parcel_id  latitude  longitude  \
# 77  Jefferson    13S13E16             100p,200p,ROW   44.4461  -121.1811
# 78  Jefferson    13S13E08             300p,400p,ROW   44.4461  -121.1811
# 79  Jefferson    13S12E12                 100p,200p   44.4461  -121.1811
# 80  Jefferson    13S13E07             400p,500p,ROW   44.4461  -121.1811
# 81  Jefferson    13S13E17                  100p,ROW   44.4461  -121.1811
# 82  Jefferson   13S13E17B  100,200,300,ROW,All part   44.4461  -121.1811
# 83  Jefferson  13S13E07DD                  100p,ROW   44.4461  -121.1811
#
#     record_ID         notes missinglot
# 77       3056  ROW, Partial          N
# 78       3057  ROW, Partial          N
# 79       3058       Partial          N
# 80       3059  ROW, Partial          N
# 81       3060  ROW, Partial          N
# 82       3061  ROW, Partial          N
# 83       3062  ROW, Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 17.8% digitized, 166 records remained, expected to be done in about 133 hours...
# WD2021-0491
# index = 85
#        county       trsqq                                         parcel_id  \
# 84  Jefferson  11S13E02AA  8500,8400,8300,8200,8100,8000,7900,7800,All part
# 85  Jefferson  11S13E02AA                  4200,5100,5000,4900,ROW,All part
# 86  Jefferson  11S13E02AA  7700,7600,7500,2300,2203,1800,1500,1504,All part
# 87  Jefferson  11S13E02AA  1503,1580,1602,1600,1400,1300,4000,4100,All part
#
#     latitude   longitude  record_ID         notes missinglot
# 84  44.64845 -121.131455       3075       Partial          N
# 85  44.64845 -121.131455       3076  ROW, Partial          N
# 86  44.64845 -121.131455       3077       Partial          N
# 87  44.64845 -121.131455       3078       Partial          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 18.3% digitized, 165 records remained, expected to be done in about 132 hours...
# WD2017-0065
# index = 89
#    county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 88   Linn  12S02W03D     1200p  44.552702 -122.911772       3081  Partial
#
#    missinglot
# 88          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 18.8% digitized, 164 records remained, expected to be done in about 131 hours...
# WD2017-0171
# index = 90
#    county      trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 89   Linn  11S03W04D      100p  44.636726 -123.060226       3088  Partial
#
#    missinglot
# 89          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 19.3% digitized, 163 records remained, expected to be done in about 130 hours...
# WD2017-0272
# index = 91
#    county     trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 90   Linn  10S03W17      403p  44.69779 -123.08053       3094  Partial
#
#    missinglot
# 90          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 19.8% digitized, 162 records remained, expected to be done in about 130 hours...
# WD2017-0311
# index = 92
#    county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 91   Linn  10S03W16     1100p  44.695684 -123.067018       3097  Partial
#
#    missinglot
# 91          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 20.3% digitized, 161 records remained, expected to be done in about 129 hours...
# WD2017-0331
# index = 93
#    county       trsqq  parcel_id   latitude   longitude  record_ID notes  \
# 92   Linn  11S03W06CD  5600, ROW  44.638689 -123.102189       3100   ROW
#
#    missinglot
# 92          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 20.8% digitized, 160 records remained, expected to be done in about 128 hours...
# WD2017-0400
# index = 94
#    county       trsqq parcel_id  latitude  longitude  record_ID    notes  \
# 93   Linn  11S03W07CC     5500p   44.6207  -123.1087       3102  Partial
#
#    missinglot
# 93          N
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 21.3% digitized, 159 records remained, expected to be done in about 127 hours...
# WD2017-0419
# index = 95
#    county       trsqq           parcel_id   latitude   longitude  record_ID  \
# 94   Linn  11S03W05DB      5600,RAILS,ROW  44.637831 -123.069913       3103
# 95   Linn  11S03W04CB                 100  44.637831 -123.069913       3104
# 96   Linn  11S03W05DD         100,202,300  44.637831 -123.069913       3105
# 97   Linn  11S03W05DA  600,3800,RAILS,ROW  44.637831 -123.069913       3106
# 98   Linn  11S03W04CC                 ROW  44.637831 -123.069913       3107
#
#         notes missinglot
# 94  ROW, Rail          N
# 95        NaN          N
# 96        NaN          N
# 97  ROW, Rail          N
# 98        ROW          Y
# Press 'p' to pause or any key to stop...p
# Press 'a' to add the wd record or 'c' to continue...c
# 21.8% digitized, 158 records remained, expected to be done in about 126 hours...
# WD2017-0578
# index = 100
#    county     trsqq parcel_id   latitude   longitude  record_ID    notes  \
# 99   Linn  15S04W09  600,607p  44.285451 -123.171464       3121  Partial
#
#    missinglot
# 99          N
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-019c3b4359f2> in <module>
# ----> 1 toadd = review_loop_r1(df=toCheck_df, partial=True, idx=True, wd_id='WD2017-0508')
#
# ~\.0GitHub\EPA-WD\wdtools.py in review_loop_r1(setID, wdid_list, df, partial, idx, wd_id, wddf)
#     152     if wd_id is None:
#     153         i = -1
# --> 154     else:
#     155         i =  wdid_list.index(wd_id)
#     156     for wdID in wdid_list[i+1:]:
#
# ~\AppData\Anaconda3\envs\geoenv\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
# --> 848         return self._input_request(str(prompt),
#     849             self._parent_ident,
#     850             self._parent_header,
#
# ~\AppData\Anaconda3\envs\geoenv\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     890             except KeyboardInterrupt:
#     891                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 892                 raise KeyboardInterrupt("Interrupted by user") from None
#     893             except Exception as e:
#     894                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
#tocheckIDs = ['WD2021-0250','WD2019-0544','WD2020-0229','WD2020-0677','WD2021-0252','WD2021-0616','WD2017-0001']

# %%
#review_loop_r1(wdid_list=tocheckIDs, partial=True, idx=True, wddf=wd)
