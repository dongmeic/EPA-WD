# %%
import geopandas as gpd

# %%
path = r'L:\NaturalResources\Wetlands\Local Wetland Inventory\WAPO\EPA_2022_Tasks\Task 1 WD Mapping\output\test'

# %%
file = path + '\\WD2021_0216L.shp'
output = path + '\\WD2021_0216_poly.shp'

# %%
linedt = gpd.read_file(file)

# %%
linedt.plot()
# Out:
# <AxesSubplot:>

# %%
linedt.convex_hull.plot()
# Out:
# <AxesSubplot:>
